# %% [markdown]
# ## Simple Linear Regression

# %% [markdown]
# ### Data Preprocessing:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split               # splitting into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Training the Linear Regression model on training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()                      # no params needed!

# %%
regressor.fit(X_train, y_train)          # training the model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Predicting the test set results

# %%
y_pred = regressor.predict(X_test)           # y_pred = predicted values
